# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df =  pd.read_csv('height-weight.csv')

# %%
df.head()
# Out:
#    Weight  Height
# 0      45     120
# 1      58     135
# 2      48     123
# 3      60     145
# 4      70     160

# %%
plt.scatter(df['Weight'],df['Height'])
plt.xlabel("Weight")
plt.ylabel("Height")
# Out:
# Text(0, 0.5, 'Height')

# %%
X=df[['Weight']]
y= df['Height']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=42)

# %%
y_train
# Out:
# 12    175
# 1     135
# 13    183
# 5     162
# 2     123
# 11    182
# 20    129
# 3     145
# 4     160
# 18    150
# 16    140
# 21    140
# 22    160
# 7     175
# 10    176
# 14    170
# 19    167
# 6     163
# Name: Height, dtype: int64

# %%
y_test
# Out:
# 15    177
# 9     170
# 0     120
# 8     182
# 17    159
# Name: Height, dtype: int64

# %%
## we need to standarize the dataset
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
plt.scatter(X_train,y_train)

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()

# %%
regressor
# Out:
# LinearRegression()

# %%
type(X_train)
# Out:
# numpy.ndarray

# %%
X_train=np.array(X_train).reshape(-1,1)
X_test=np.array(X_test).reshape(-1,1)

# %%
y_train.shape
# Out:
# (18,)

# %%
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
## printing the coefficient and intercept
print("Coefficient:",regressor.coef_)
print("Intercept:",regressor.intercept_)
# Out:
# Coefficient: [17.03440872]
# Intercept: 157.5

# %%
plt.scatter(X_train,y_train)
plt.plot(X_train,regressor.predict(X_train))

# %% [markdown]
# ### prediction of train data
# 1. predicted height output= intercept +coef_(Weights)
# 2. y_pred_train =65.4364 + 1.26(X_train)
#
# ### prediction of test data
# 1. predicted height output= intercept +coef_(Weights)
# 2. y_pred_test =65.4364 + 1.26(X_test)

# %%
y_pred_test=regressor.predict(X_test)

# %%
y_test
# Out:
# 15    177
# 9     170
# 0     120
# 8     182
# 17    159
# Name: Height, dtype: int64

# %%
plt.scatter(X_test,y_test)
plt.plot(X_test,regressor.predict(X_test))

# %% [markdown]
# ### Performance metrics

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
mse=mean_squared_error(y_test,y_pred_test)
mae=mean_absolute_error(y_test,y_pred_test)
rmse=np.sqrt(mse)
print(mse)
print(mae)
print(rmse)
# Out:
# 109.77592599051664
# 9.822657814519232
# 10.477400726827081

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred_test)

# %%
print(score)
# Out:
# 0.776986986042344

# %% [markdown]
# ## R square
# Formula
#
# **R^2 = 1 - SSR/SST**
#
#
# R^2	=	coefficient of determination
# SSR	=	sum of squares of residuals
# SST	=	total sum of squares

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred_test)
print(score)
# Out:
# 0.776986986042344

# %% [markdown]
# ## Assumptions
#
# ## plot a scatter plot for the prediction
# plt.scatter(y_test,y_pred_test)

# %%
## Residuals
residuals=y_test-y_pred_test

residuals
# Out:
# 15    15.915329
# 9      8.915329
# 0     -9.304156
# 8      4.543549
# 17    10.434926
# Name: Height, dtype: float64

# %%
## Plot this residuals 
import seaborn as sns
sns.displot(residuals,kind="kde")

# %%
## Scatter plot with respect to prediction and residuals
## uniform distribution
plt.scatter(y_pred_test,residuals)

# %% [markdown]
# ### OLS

# %%
import statsmodels.api as sm

# %%
model = sm.OLS(y_train, X_train).fit()
predictions = model.predict(X_test)

# %%
print(model.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                 Height   R-squared (uncentered):                   0.012
# Model:                            OLS   Adj. R-squared (uncentered):             -0.047
# Method:                 Least Squares   F-statistic:                             0.1986
# Date:                Tue, 05 Nov 2024   Prob (F-statistic):                       0.661
# Time:                        20:30:40   Log-Likelihood:                         -116.62
# No. Observations:                  18   AIC:                                      235.2
# Df Residuals:                      17   BIC:                                      236.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            17.0344     38.226      0.446      0.661     -63.616      97.684
# ==============================================================================
# Omnibus:                        0.849   Durbin-Watson:                   0.003
# Prob(Omnibus):                  0.654   Jarque-Bera (JB):                0.661
# Skew:                          -0.428   Prob(JB):                        0.718
# Kurtosis:                       2.614   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /opt/miniconda3/lib/python3.12/site-packages/scipy/stats/_axis_nan_policy.py:418: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=18 observations were given.
#   return hypotest_fun_in(*args, **kwds)
